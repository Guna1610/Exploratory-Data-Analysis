# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./EDA Projects/archive/dataset_olympics.csv' )
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      70000 non-null  int64
#  1   Name    70000 non-null  object
#  2   Sex     70000 non-null  object
#  3   Age     67268 non-null  float64
#  4   Height  53746 non-null  float64
#  5   Weight  52899 non-null  float64
#  6   Team    70000 non-null  object
#  7   NOC     70000 non-null  object
#  8   Games   70000 non-null  object
#  9   Year    70000 non-null  int64
#  10  Season  70000 non-null  object
#  11  City    70000 non-null  object
#  12  Sport   70000 non-null  object
#  13  Event   70000 non-null  object
#  14  Medal   9690 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 8.0+ MB

# %%
df.shape
# Out:
# (70000, 15)

# %%
df.isna().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2732
# Height    16254
# Weight    17101
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     60310
# dtype: int64

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
df.Sex.value_counts().plot(kind='bar')
plt.xlabel('SEX')
plt.ylabel('FREQUENCY')
plt.title('MALE vs FEMALE')
plt.show()

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
new_df = df.dropna(subset = ['Medal'])

# %%
new_df.isna().sum()
# Out:
# ID           0
# Name         0
# Sex          0
# Age        185
# Height    2317
# Weight    2518
# Team         0
# NOC          0
# Games        0
# Year         0
# Season       0
# City         0
# Sport        0
# Event        0
# Medal        0
# dtype: int64

# %%
new_df.head(2)
# Out:
#     ID                  Name Sex   Age  Height  Weight            Team  NOC  \
# 3    4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 37  15  Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  1920 Summer  1920  Summer  Antwerpen    Swimming
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze

# %%
new_df.groupby('Sex')['Season'].value_counts()
# Out:
# Sex  Season
# F    Summer    2171
#      Winter     428
# M    Summer    6233
#      Winter     858
# Name: count, dtype: int64

# %%
new_df.City.value_counts()
# Out:
# City
# London                    971
# Athina                    605
# Los Angeles               574
# Rio de Janeiro            519
# Beijing                   481
# Sydney                    436
# Paris                     423
# Atlanta                   415
# Barcelona                 411
# Seoul                     372
# Antwerpen                 371
# Moskva                    329
# Montreal                  319
# Munich                    272
# Stockholm                 247
# Tokyo                     246
# Roma                      236
# Helsinki                  221
# Mexico City               214
# Berlin                    213
# Melbourne                 209
# Amsterdam                 196
# Torino                    126
# St. Louis                 124
# Sochi                     124
# Salt Lake City            120
# Vancouver                  97
# Nagano                     88
# Lillehammer                87
# Innsbruck                  77
# Lake Placid                74
# ...

# %%
new_df.head(2)
# Out:
#     ID                  Name Sex   Age  Height  Weight            Team  NOC  \
# 3    4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 37  15  Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War
# 37  1920 Summer  1920  Summer  Antwerpen    Swimming
#
#                                      Event   Medal
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze

# %%
drop_df = new_df.dropna(subset = ['Height','Weight','Age'])

# %%
drop_df.isna().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
drop_df.head(2)
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
drop_df.Event
# Out:
# 40                  Ice Hockey Men's Ice Hockey
# 41       Gymnastics Men's Individual All-Around
# 42             Gymnastics Men's Team All-Around
# 44                 Gymnastics Men's Horse Vault
# 48             Gymnastics Men's Pommelled Horse
#                           ...
# 69912                 Football Women's Football
# 69952               Ice Hockey Men's Ice Hockey
# 69974      Athletics Women's 100 metres Hurdles
# 69983         Rugby Sevens Women's Rugby Sevens
# 69988            Speed Skating Men's 500 metres
# Name: Event, Length: 7101, dtype: object

# %%
drop_df.describe()
# Out:
#                  ID          Age       Height       Weight         Year
# count   7101.000000  7101.000000  7101.000000  7101.000000  7101.000000
# mean   18307.943811    25.458668   178.003098    73.927053  1988.124208
# std    10244.627252     5.115223    10.787812    15.143549    22.978736
# min       16.000000    13.000000   136.000000    30.000000  1896.000000
# 25%     9419.000000    22.000000   170.000000    63.000000  1976.000000
# 50%    17985.000000    25.000000   178.000000    73.000000  1992.000000
# 75%    27601.000000    28.000000   185.000000    83.000000  2006.000000
# max    35653.000000    58.000000   223.000000   170.000000  2016.000000

# %%
data = drop_df

# %%
data.head(2)
# Out:
#     ID                      Name Sex   Age  Height  Weight     Team  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season    City       Sport  \
# 40  2014 Winter  2014  Winter   Sochi  Ice Hockey
# 41  1948 Summer  1948  Summer  London  Gymnastics
#
#                                      Event   Medal
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
data.NOC.value_counts()
# Out:
# NOC
# USA    1233
# URS     450
# ITA     409
# FRA     336
# AUS     331
#        ...
# MDA       1
# SEN       1
# CIV       1
# PHI       1
# DOM       1
# Name: count, Length: 114, dtype: int64

# %%
df.describe(include=['object'])
# Out:
#                                     Name    Sex           Team    NOC  \
# count                              70000  70000          70000  70000
# unique                             35556      2            827    226
# top     Oksana Aleksandrovna Chusovitina      M  United States    USA
# freq                                  29  51877           4979   5216
#
#               Games  Season    City      Sport                    Event Medal
# count         70000   70000   70000      70000                    70000  9690
# unique           51       2      42         65                      744     3
# top     2016 Summer  Summer  London  Athletics  Football Men's Football  Gold
# freq           3675   58467    6034      10629                     1738  3292

# %%
df.duplicated().sum()
# Out:
# np.int64(383)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# To visualize charts for categorical values we will use countplot
sns.countplot(data = df, x='Sex')
plt.title('Distribution of Gender')
plt.show()

# %%
# To visualize charts for numerical values we will use histplot
sns.histplot(data= df, x = 'Age', bins = 10, kde = True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(data = data, x='Height', kde = True, bins = 20)
plt.title("Distribution of Height")
plt.show()

# %%
sns.histplot(data = df, x= 'Weight' ,bins = 20, kde= True)
plt.title('Distribution of Weight')
plt.show()

# %%
sns.countplot(data = df, x= 'Medal',color='lightblue')
plt.title("Medal Distribution")
plt.show()

# %%
df.Medal.value_counts()
# Out:
# Medal
# Gold      3290
# Bronze    3208
# Silver    3188
# Name: count, dtype: int64

# %%
sns.countplot(data = df, x='Year',hue= 'Sex')
plt.title("Age Distribution Over the Years")
plt.xticks(rotation =45)
plt.show()

# %%
sns.countplot(data = df, x = 'Year', hue='Medal')
plt.title("Medal Distribution Over the Years")
plt.xticks(rotation = 60)
plt.show()

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
year_avg_age = df.groupby('Year')['Age'].mean()

# %%
year_avg_age
# Out:
# Year
# 1896    23.029412
# 1900    29.119883
# 1904    27.063241
# 1906    26.989474
# 1908    27.000000
# 1912    27.965552
# 1920    29.241135
# 1924    28.252267
# 1928    27.973564
# 1932    29.606987
# 1936    27.245665
# 1948    28.363170
# 1952    26.273684
# 1956    26.316156
# 1960    25.136156
# 1964    24.852107
# 1968    24.316722
# 1972    24.126448
# 1976    23.656820
# 1980    23.312364
# 1984    24.060328
# 1988    24.257374
# 1992    24.637827
# 1994    24.487516
# 1996    25.338210
# 1998    25.143860
# 2000    25.435177
# 2002    26.029095
# 2004    25.780111
# 2006    26.091716
# 2008    25.685148
# 2010    26.150776
# 2012    25.993485
# 2014    26.082814
# 2016    26.259592
# Name: Age, dtype: float64

# %%
sport_median_height = df.groupby('Sport')['Height'].median()

# %%
sport_median_height.max()
# Out:
# 190.0

# %%
sport_median_height[sport_median_height == 190.00]
# Out:
# Sport
# Basketball    190.0
# Name: Height, dtype: float64

# %%
sport_median_height.min()
# Out:
# 164.0

# %%
sport_median_height[sport_median_height == 164.0]
# Out:
# Sport
# Gymnastics    164.0
# Name: Height, dtype: float64

# %%
df.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
country_gender_count = df.groupby(['NOC','Sex'])['ID'].count()
country_gender_count
# Out:
# NOC  Sex
# AFG  M       38
# AHO  F        6
#      M       27
# ALB  F        4
#      M        7
#            ...
# YUG  M      455
# ZAM  F        3
#      M       40
# ZIM  F       41
#      M       47
# Name: ID, Length: 432, dtype: int64

# %%
country_gold_medals = df[df['Medal'] == 'Gold'].groupby('NOC')['Medal'].count()
country_gold_medals
# Out:
# NOC
# ALG      1
# ANZ      7
# ARG     25
# ARM      1
# AUS     98
#       ...
# URU     13
# USA    747
# UZB      4
# YUG     31
# ZIM      7
# Name: Medal, Length: 84, dtype: int64

# %%
country_gold_medals.max()
# Out:
# 747

# %%
country_gold_medals[country_gold_medals == 747]
# Out:
# NOC
# USA    747
# Name: Medal, dtype: int64

# %%
sport_gender_avg_weight = df.groupby(['Sport','Age'])['Weight'].mean()
sport_gender_avg_weight
# Out:
# Sport          Age
# Alpine Skiing  14.0     54.600000
#                15.0     69.000000
#                16.0     62.821429
#                17.0     66.864407
#                18.0     63.709091
#                           ...
# Wrestling      37.0     97.000000
#                38.0    100.000000
#                39.0     86.500000
#                40.0           NaN
#                41.0           NaN
# Name: Weight, Length: 1497, dtype: float64

# %%
print(sport_gender_avg_weight['Wrestling']['F'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\desktop\ML\heart_disease_project\env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:19, in pandas._libs.index.Float64Engine._check_type()
#
# KeyError: 'F'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 print(sport_gender_avg_weight['Wrestling']['F'])
#
# ...

# %%
sport_event_count = df.groupby('Sport')['Event'].nunique().sort_values(ascending = False)
sport_event_count
# Out:
# Sport
# Athletics     83
# Shooting      81
# Swimming      54
# Cycling       42
# Sailing       37
#               ..
# Polo           1
# Roque          1
# Rugby          1
# Softball       1
# Tug-Of-War     1
# Name: Event, Length: 65, dtype: int64

# %%
sport_event_count.plot(kind = 'bar')
plt.title('No.of Unique Events Per Sport')
plt.xlabel('Sport')
plt.ylabel('Number of Unique Events')
plt.show()

# %%
year_participant_count = df.groupby('Year')['ID'].nunique()
year_participant_count
# Out:
# Year
# 1896      34
# 1900     433
# 1904     167
# 1906     203
# 1908     578
# 1912     609
# 1920     797
# 1924    1060
# 1928     990
# 1932     591
# 1936    1327
# 1948    1456
# 1952    1518
# 1956    1071
# 1960    1637
# 1964    1551
# 1968    1758
# 1972    2111
# 1976    1848
# 1980    1651
# 1984    2237
# 1988    2622
# 1992    2892
# 1994     420
# 1996    2677
# 1998     510
# 2000    2796
# 2002     536
# 2004    2719
# 2006     565
# 2008    2792
# 2010     521
# 2012    2769
# 2014     605
# 2016    3003
# Name: ID, dtype: int64

# %%
year_participant_count.plot(kind = 'bar')
plt.title('No.Of Participants Over the Years')
plt.xlabel('Year')
plt.ylabel('No.Of Participants')
plt.show()

# %%
country_avg_age = df.groupby('NOC')['Age'].mean().sort_values(ascending = False)
country_avg_age
# Out:
# NOC
# WIF    34.600000
# MON    31.611111
# DMA    30.000000
# TLS    28.333333
# CAY    28.181818
#          ...
# LAO    20.000000
# YMD    20.000000
# KIR    17.000000
# CRT          NaN
# UNK          NaN
# Name: Age, Length: 226, dtype: float64

# %%
country_avg_age.head(10).plot(kind ='bar')
plt.title('Top 10 Countries with Highest Average Age of Participants')
plt.xlabel('Country')
plt.ylabel('Average Age')
plt.xticks(rotation = 45)
plt.show()

# %%
country_avg_age.tail(10).plot(kind ='bar')
plt.title('Top 10 Countries with Lowest Average Age of Participants')
plt.xlabel('Country')
plt.ylabel('Average Age')
plt.xticks(rotation = 45)
plt.show()

# %%
sns.boxplot( data = df, x = 'Season', y = "Age")
plt.title('Distribution of Age by Season')
plt.xlabel('Season')
plt.ylabel('Age')
plt.show()

# %%
sns.violinplot(data = df, hue= 'Medal', y ='Height', palette ='Set2')
plt.title('Distribution of Heights by Medal')
plt.xlabel('Medal')
plt.ylabel('Height')
plt.show()

# %%
most_medals_country = data['NOC'].value_counts().idxmax()
print('Most Medal-Winning Country: ',most_medals_country)
# Out:
# Most Medal-Winning Country:  USA

# %%
tallest_athlete = df[df['Height'] == df['Height'].max()]
print('Tallest Athlete: ')
print(tallest_athlete[['ID','Name','Height','Sport']])
# Out:
# Tallest Athlete:
#           ID                  Name  Height       Sport
# 32376  16639  Tommy Loren Burleson   223.0  Basketball

# %%
heaviest_athlete = df[df['Weight'] == df['Weight'].min()]
print('Heaviest_athlete: ')
print(heaviest_athlete[['ID','Name','Height','Sport','Year']])
# Out:
# Heaviest_athlete:
#           ID            Name  Height       Sport  Year
# 40849  21049  Choi Myong-Hui   135.0  Gymnastics  1980
# 40850  21049  Choi Myong-Hui   135.0  Gymnastics  1980
# 40851  21049  Choi Myong-Hui   135.0  Gymnastics  1980
# 40852  21049  Choi Myong-Hui   135.0  Gymnastics  1980
# 40853  21049  Choi Myong-Hui   135.0  Gymnastics  1980
# 40854  21049  Choi Myong-Hui   135.0  Gymnastics  1980

# %%
sns.scatterplot(data = df, x='Height', y='Weight', hue='Medal', palette = 'Set2')
plt.title('Athlete Height Vs Weight By Medal Status')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend(title = 'Medal')
plt.show()

# %%
medals_by_country_year = df.pivot_table(index = 'NOC', columns='Year', values ='Medal', aggfunc='count')
sns.heatmap(medals_by_country_year, linewidths = 0.5)
plt.title('Medals Counts Country By Year')
plt.xlabel('Year')
plt.ylabel('Country')
plt.xticks(rotation = 45)
plt.show()

# %%
df.groupby('Medal')['NOC'].value_counts()
# Out:
# Medal   NOC
# Bronze  USA    366
#         FRA    257
#         ITA    194
#         GBR    186
#         AUS    151
#               ...
# Silver  TAN      1
#         THA      1
#         TJK      1
#         UAR      1
#         UZB      1
# Name: count, Length: 282, dtype: int64
