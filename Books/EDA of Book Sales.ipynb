# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("EDA Projects/archive/Books_Data_Clean.csv")
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         1
# Book Name              23
# Author                  0
# language_code          53
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dtypes
# Out:
# index                    int64
# Publishing Year        float64
# Book Name               object
# Author                  object
# language_code           object
# Author_Rating           object
# Book_average_rating    float64
# Book_ratings_count       int64
# genre                   object
# gross sales            float64
# publisher revenue      float64
# sale price             float64
# sales rank               int64
# Publisher               object
# units sold               int64
# dtype: object

# %%
df.Author
# Out:
# 0                                  Unknown, Seamus Heaney
# 1       Frank Miller, David Mazzucchelli, Richmond Lew...
# 2                                              Harper Lee
# 3                                           David Sedaris
# 4                                            Laini Taylor
#                               ...
# 1065                                         John Grisham
# 1066                                      Bryce Courtenay
# 1067                                     Dashiell Hammett
# 1068                                       Kristin Hannah
# 1069                                            Lee Child
# Name: Author, Length: 1070, dtype: object

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df = df[df['Publishing Year']>1900]

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset = "Book Name", inplace = True)
# Out:
# C:\Users\G.Guna\AppData\Local\Temp\ipykernel_33808\552555317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = "Book Name", inplace = True)

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name               0
# Author                  0
# language_code          47
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset = "language_code" ,inplace = True)
# Out:
# C:\Users\G.Guna\AppData\Local\Temp\ipykernel_33808\3335375232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = "language_code" ,inplace = True)

# %%
df.isna().sum()
# Out:
# index                  0
# Publishing Year        0
# Book Name              0
# Author                 0
# language_code          0
# Author_Rating          0
# Book_average_rating    0
# Book_ratings_count     0
# genre                  0
# gross sales            0
# publisher revenue      0
# sale price             0
# sales rank             0
# Publisher              0
# units sold             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# index                  941
# Publishing Year        100
# Book Name              940
# Author                 647
# language_code            8
# Author_Rating            4
# Book_average_rating    132
# Book_ratings_count     936
# genre                    4
# gross sales            737
# publisher revenue      544
# sale price             135
# sales rank             785
# Publisher                9
# units sold             463
# dtype: int64

# %%
plt.hist(df['Publishing Year'])
plt.xlabel("publishing year")
plt.ylabel("frequency")
plt.title('Distribution of Publishing Year')
plt.show()

# %%
df.head(2)
# Out:
#    index  Publishing Year         Book Name  \
# 0      0           1975.0           Beowulf
# 1      1           1987.0  Batman: Year One
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000
# 1  HarperCollins Publishers        6250

# %%
df.genre.value_counts().plot(kind = 'bar')
plt.xlabel('Genre')
plt.ylabel('Number of Books')
plt.title('Number of Books in Each Genre')
plt.show()

# %%
df.groupby('Author')['Book_average_rating'].mean().sort_values(ascending = True)
# Out:
# Author
# Sue Monk Kidd                   3.100000
# P.D. James                      3.210000
# Herman Koch, Sam Garrett        3.220000
# Audrey Niffenegger              3.230000
# Chetan Bhagat                   3.273333
#                                   ...
# Sarah J. Maas                   4.526000
# George R.R. Martin              4.560000
# J.R.R. Tolkien                  4.590000
# Bill Watterson, G.B. Trudeau    4.610000
# Bill Watterson                  4.650000
# Name: Book_average_rating, Length: 647, dtype: float64

# %%
sns.boxplot(x= 'genre', y = 'Book_ratings_count', data= df)
plt.xlabel('Genre')
plt.ylabel('Books Ratings Count')
plt.title('Box plot of Book rating Count for Each Genre')
plt.show()

# %%
plt.scatter(df['sale price'], df['units sold'])
plt.xlabel('sale price')
plt.ylabel('units sold')
plt.title('Scatter plot of sale price vs units sold')
plt.show()

# %%
df.head(2)
# Out:
#    index  Publishing Year         Book Name  \
# 0      0           1975.0           Beowulf
# 1      1           1987.0  Batman: Year One
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# 1  Intermediate                 4.23              145267  genre fiction
#
#    gross sales  publisher revenue  sale price  sales rank  \
# 0      34160.0            20496.0        4.88           1
# 1      12437.5             7462.5        1.99           2
#
#                  Publisher   units sold
# 0  HarperCollins Publishers        7000
# 1  HarperCollins Publishers        6250

# %%
language_counts = df['language_code'].value_counts()

# %%
plt.pie(language_counts, labels = language_counts.index, startangle= 90, autopct = "%1.1f%%")
plt.title("Language Distribution of Books")
plt.show()

# %%
df.groupby("Publisher ")['publisher revenue'].sum().sort_values(ascending = False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 186885.492
# Random House LLC                        167535.750
# Amazon Digital Services,  Inc.          137652.264
# HarperCollins Publishers                121086.432
# Hachette Book Group                      99748.464
# Simon and Schuster Digital Sales Inc     46434.336
# Macmillan                                30770.364
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.groupby('Author_Rating')['Book_ratings_count'].mean().sort_values(ascending= False).max()
# Out:
# 102053.91970802919

# %%
df.groupby('language_code').size().sort_values(ascending = False)
# Out:
# language_code
# eng      670
# en-US    226
# en-GB     29
# en-CA      7
# fre        4
# ara        2
# spa        2
# nl         1
# dtype: int64

# %%
author_rating=df['Author_Rating'].value_counts()

# %%
plt.pie(author_rating,labels= author_rating.index,startangle = 90)
plt.title("Ratings")
plt.show()

# %%
plt.scatter(df['Book_average_rating'],df['Book_ratings_count'])
plt.xlabel('Book Avg Rating')
plt.ylabel('Book Ratings Counts')
plt.title("Scatter plot of Book Avg Rating vs Book Ratings Counts")
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
total_gross_sales_by_author = df.groupby('Author')['gross sales'].sum()

# %%
total_gross_sales_by_author.sort_values(ascending= False).head(20).plot(kind = 'bar',xlabel ='Author', ylabel = 'Total Gross Sales')
plt.title('Total Gross Sales for each Author')
plt.show()

# %%
sns.boxplot(x= "Author_Rating", y = "units sold", data= df)
plt.xlabel("Author Rating")
plt.ylabel("Units Sold")
plt.title("Box Plot of Units Sold for Each Author Rating")
plt.show()

# %%
df.groupby("Publishing Year")['units sold'].sum().plot(kind='line',marker='.')
plt.xlabel("Publishing Year")
plt.ylabel("Toatal Units Sold")
plt.title("Totals Units Sold Over The Years")
plt.show()
